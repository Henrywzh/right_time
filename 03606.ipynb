# %%
import matplotlib.pyplot as plt

from finance_utils.backtest import Backtest
from finance_utils.utils import *
import yfinance as yf
import pandas as pd

start_date = '2000-01-01'
df = yf.download('3606.HK', start=start_date)

df_new = pd.DataFrame()
df_new['Price'] = df['Adj Close']
df_new['Value'] = df['Adj Close']
df_new['Return'] = df['Adj Close'].pct_change()

test_3606 = Backtest(df_new)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# ---- Running the backtest... ----
#
# ---- Backtesting completed ----
#
# Annualised Return (Geo): 0.12290656718805293
# Avg Annual Return (Ari): 0.13599572340685362
# Volatility (Std): 0.398661942672344
# Sharpe Ratio: 0.30829771802187933
# Downside Volatility: 0.259469819872356
# Sortino Ratio: 0.4736834798302006
# VaR 99: -0.061056999890694616
# VaR 99 (Year): -0.23244460135619757
# CVaR 99: -0.07832637288511034
# CVaR 99 (Year): -0.23244460135619757
# Initial Value: 13.549891471862793
# Peak Value: 58.35298156738281
# Final Value: 39.04999923706055
# Max Drawdown: 0.6015140403758046
# Avg Drawdown: 0.2546715857541211
# Calmar Ratio: 0.20432867553892053
# Sterling Ratio: 0.4826080884685584
# Monthly Stats:
#            mean        std    median         q1         q3        max  \
# Month
# 1      1.303198  11.246303 -3.556487  -6.490068   9.657949  19.601318
# 2     -3.047496   7.845473 -3.384611 -11.162787   2.372264   6.512887
# 3     -4.218921  13.215601 -4.723302 -11.055311   0.095302  19.490449
# 4      0.523753   8.192691  0.677353  -4.368824   3.361191  17.185538
# 5      5.249731  10.218007  6.861954  -1.112331  11.668661  19.775029
# 6      2.285816   7.845940  2.780050   1.465877   7.070494  13.684223
# 7     -0.022068   9.600099 -3.091660  -8.165898   7.242642  17.957003
# 8     -1.946693   5.741557 -2.722272  -5.033591   2.157492   7.543100
# 9      0.559005   9.046554  0.419584  -0.457656   3.667479  15.478610
# 10     1.610843   9.710801  0.894851  -0.599501   4.028029  17.531291
# 11     4.634924   6.259057  2.439018   1.470600   6.211927  15.756635
# 12     2.960384   5.863629  3.023773  -1.377964   6.136349  13.147406
#
#              min
# Month
# 1     -12.583518
# 2     -14.542200
# 3     -25.982143
# 4     -12.600974
# 5     -14.128434
# 6     -13.727263
# 7     -10.118045
# 8     -13.001211
# 9     -14.324324
# 10    -13.745918
# 11     -2.828055
# 12     -4.161704

# %%
plot_monthly_box(test_3606.results['Monthly Return'])

# %% [markdown]
# check +- 1 month price change for reports

# %%
interim_dates = [
    '2015-08-31', '2016-09-05', '2017-08-10', '2018-08-23', '2019-09-11', '2020-09-03', 
    '2021-08-19', '2022-09-13', '2023-09-05', '2024-08-06'
]

interim_dates = pd.to_datetime(interim_dates)

for date in interim_dates:
    days = pd.to_timedelta(42, unit='d')
    data = df['Adj Close'].loc[date - days : date + days]
    fig, ax = plt.subplots(figsize=(10, 6))
    plt.plot(data, label='Price')
    plt.plot(date, data.loc[date], marker='^', color='r', label='Report Released')
    plt.legend()
    plt.ylabel('Price')
    plt.title('Impact of Interim Report Release to Stock Price')
    plt.show()

# %%
start_date = '2015-03-31'
# start_date = '2000-03-31'
df = yf.download('0868.HK', start=start_date)

df_new = pd.DataFrame()
df_new['Price'] = df['Adj Close']
df_new['Value'] = df['Adj Close']
df_new['Return'] = df['Adj Close'].pct_change()

test_0868 = Backtest(df_new)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# ---- Running the backtest... ----
#
# ---- Backtesting completed ----
#
# Annualised Return (Geo): 0.12007093498508281
# Avg Annual Return (Ari): 0.1826593298008638
# Volatility (Std): 0.40812669587672395
# Sharpe Ratio: 0.294200149605873
# Downside Volatility: 0.27288487562880137
# Sortino Ratio: 0.440005825564376
# VaR 99: -0.06166737338521161
# VaR 99 (Year): -0.3888861237099576
# CVaR 99: -0.07970943830943636
# CVaR 99 (Year): -0.3888861237099576
# Initial Value: 2.727109909057617
# Peak Value: 28.450611114501953
# Final Value: 7.679999828338623
# Max Drawdown: 0.7909492418837523
# Avg Drawdown: 0.28993778376301366
# Calmar Ratio: 0.15180611931445523
# Sterling Ratio: 0.4141265530374101
# Monthly Stats:
#            mean        std    median         q1         q3        max  \
# Month
# 1     -1.106771  13.992635  6.514995 -15.151513  10.220083  11.662197
# 2      1.792290  11.489748 -1.128201  -3.037374   6.201523  25.984254
# 3     -1.376880  10.556143 -4.267920  -7.066633   2.332090  22.802858
# 4      0.806195   4.546608  2.026217  -1.450420   3.464575   8.039212
# 5      0.183233  12.513430 -1.785952  -9.114222   9.458000  21.568630
# 6      0.843435   8.998022  3.269013  -8.009571   7.502857  12.038474
# 7      0.038237   8.439526  0.621904  -4.121020   2.041851  17.720213
# 8      2.633557   9.382142  2.484228  -3.987416  10.810753  15.885689
# 9     -3.859360  13.304559 -0.288216 -16.885242   5.891236  12.898543
# 10    -3.401442   9.896887 -3.080877  -7.510289   2.570102   8.429109
# 11     6.034456  15.988511  3.225811   1.352878   5.125019  36.745870
# 12     6.939543   7.908221  9.352521   1.271685   9.878701  21.766024
#
#              min
# Month
# 1     -23.396683
# 2     -14.767446
# 3     -12.844033
# 4      -8.307371
# 5     -18.220333
# 6     -11.000730
# 7     -15.148174
# 8     -12.953941
# 9     -25.200632
# 10    -20.654392
# 11    -12.556735
# 12     -4.625539

# %%
plot_monthly_box(test_0868.results['Monthly Return'])

# %%
# start_date = '2015-03-31'
start_date = '1900-01-01'
df = yf.download('ASGLY', start=start_date)

df_new = pd.DataFrame()
df_new['Price'] = df['Adj Close']
df_new['Value'] = df['Adj Close']
df_new['Return'] = df['Adj Close'].pct_change()

test_asgly = Backtest(df_new)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# ---- Running the backtest... ----
#
# ---- Backtesting completed ----
#
# Annualised Return (Geo): -0.03616010229946043
# Avg Annual Return (Ari): -0.011066099037965729
# Volatility (Std): 0.30867804272318816
# Sharpe Ratio: -0.11714504206535857
# Downside Volatility: 0.2199146681482484
# Sortino Ratio: -0.1644278783399944
# VaR 99: -0.05362229754765382
# VaR 99 (Year): -0.3132910819375283
# CVaR 99: -0.06761567618746091
# CVaR 99 (Year): -0.3132910819375283
# Initial Value: 9.800000190734863
# Peak Value: 14.100000381469727
# Final Value: 5.730000019073486
# Max Drawdown: 0.6985815684384402
# Avg Drawdown: 0.4637121167862592
# Calmar Ratio: -0.051762176291438894
# Sterling Ratio: -0.0779796364823649
# Monthly Stats:
#            mean        std    median        q1        q3        max        min
# Month
# 1      1.119620   7.048486  0.576028 -4.297681  7.328144   9.595200 -11.930293
# 2      0.514716  10.794894  1.381221 -4.033546  6.191363  18.867924 -20.598003
# 3      1.581532   8.480313  2.370368 -1.534093  5.701600  14.597540 -16.462348
# 4      3.290324   7.287761  1.970441 -2.623010  8.769057  16.191903  -7.835822
# 5     -3.158922   7.625949 -5.333335 -7.940458 -1.196889  18.736839 -12.319791
# 6     -3.055046   7.245022 -5.018358 -8.789974  2.399855  10.789051 -10.467289
# 7     -0.535188   7.437563 -1.260500 -4.130113  3.997264  11.096429 -12.391933
# 8     -3.990754   7.196343 -2.916158 -6.900806 -1.438437   9.773123 -18.259631
# 9      2.018949   4.652892  3.205632 -1.471344  5.706001   8.374380  -6.456454
# 10    -0.313698   8.565909 -1.038346 -3.501586  6.301679  13.474025 -21.889946
# 11     2.531416   6.645399  2.437364 -1.298165  6.359197  15.015637  -8.587783
# 12    -0.224804   3.830212 -1.224489 -2.857016  1.913660   6.005458  -5.202314

# %%
plot_monthly_box(test_asgly.results['Monthly Return'])

# %%
# start_date = '2015-03-31'
start_date = '1900-01-01'
df = yf.download('SGO.PA', start=start_date)

df_new = pd.DataFrame()
df_new['Price'] = df['Adj Close']
df_new['Value'] = df['Adj Close']
df_new['Return'] = df['Adj Close'].pct_change()

test_sgo = Backtest(df_new)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# ---- Running the backtest... ----
# ---- Backtesting completed ----
#
# Annualised Return (Geo): 0.04683106034344253
# Avg Annual Return (Ari): 0.07317030766674555
# Volatility (Std): 0.3471448943608996
# Sharpe Ratio: 0.1349034973700518
# Downside Volatility: 0.2414903282013429
# Sortino Ratio: 0.19392520061671817
# VaR 99: -0.060329342043275155
# VaR 99 (Year): -0.44052066314512817
# CVaR 99: -0.08405303504903236
# CVaR 99 (Year): -0.44052066314512817
# Initial Value: 23.122615814208984
# Peak Value: 80.48146057128906
# Final Value: 72.87999725341797
# Max Drawdown: 0.7840995316207984
# Avg Drawdown: 0.30878989409443564
# Calmar Ratio: 0.059725912916487614
# Sterling Ratio: 0.1516599514397334
# Monthly Stats:
#            mean        std    median        q1        q3        max        min
# Month
# 1     -0.758664  10.375335  2.650870 -4.238235  5.852929  12.481403 -25.518496
# 2     -0.279662   8.319117  0.744208 -3.097042  4.903907  14.564142 -30.421572
# 3     -0.444256   9.087531  0.887334 -4.997114  4.414307  17.561930 -30.560767
# 4      4.639482   8.021881  3.922002  1.658623  4.821284  27.123669  -7.489933
# 5     -0.128198   8.030724 -0.399725 -3.284084  3.470601  25.844141 -15.765461
# 6     -1.735708   8.727862 -0.363570 -6.534654  3.504889   9.908683 -22.920202
# 7      1.478342  10.403236  3.899407 -1.138530  8.378588  14.903055 -32.341833
# 8     -0.437802   6.394536 -0.236142 -4.582352  4.041634  10.649087 -14.108265
# 9     -2.908780   9.368876 -2.833745 -6.476857  1.705823  18.068271 -25.508516
# 10     0.182354   6.981732  0.193819 -4.098056  3.358624  17.858993 -15.943427
# 11     4.824750   9.840388  3.588562  0.123516  7.546529  41.717217  -7.841206
# 12     1.655464   6.315984  1.674083 -2.374750  5.617735  13.133547 -10.009671

# %%
plot_monthly_box(test_sgo.results['Monthly Return'])
