# %%
from datetime import datetime

from finance_utils.backtest import Backtest
import yfinance as yf
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

from_beginning = '1987-01-01'
# hang seng index start: 1987-01-01
name = '^HSI'

start_date = from_beginning
df = yf.download(name, start=start_date)

df1 = pd.DataFrame()
df1['Price'] = df['Adj Close']
df1['Value'] = df['Adj Close']
df1['Return'] = df['Adj Close'].pct_change()

test_df = Backtest(df1)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# ---- Running the backtest... ----
# ---- Backtesting completed ----
#
# Annualised Return (Geo): 0.05376498185401446
# Avg Annual Return (Ari): 0.08824231917908681
# Volatility (Std): 0.25600635996940707
# Sharpe Ratio: 0.21001424285099562
# Downside Volatility: 0.18372945599567833
# Sortino Ratio: 0.2926312580780684
# VaR 99: -0.042212127319421436
# VaR 99 (Year): -0.4779677337926634
# CVaR 99: -0.06390772924618005
# CVaR 99 (Year): -0.4779677337926634
# Initial Value: 2540.10009765625
# Peak Value: 33154.12109375
# Final Value: 17503.33984375
# Max Drawdown: 0.6518186042408531
# Avg Drawdown: 0.25434419095571303
# Calmar Ratio: 0.08248457700380057
# Sterling Ratio: 0.21138671047288096
# Monthly Stats:
#       count      mean       std       min       25%       50%       75%  \
# Date
# 1      38.0  0.001088  0.073812 -0.148937 -0.055700  0.007082  0.056914
# 2      38.0  0.015634  0.060133 -0.119786 -0.018577  0.012509  0.064854
# 3      38.0 -0.008796  0.051546 -0.111411 -0.035755 -0.002851  0.020755
# 4      38.0  0.023546  0.059882 -0.083637 -0.011863  0.017308  0.051096
# 5      38.0 -0.000201  0.074352 -0.154219 -0.049281  0.000108  0.038512
# 6      38.0 -0.001930  0.053999 -0.154684 -0.037130 -0.002623  0.036357
# 7      38.0  0.015839  0.060027 -0.104889 -0.027868  0.035173  0.054383
# 8      38.0 -0.018700  0.054673 -0.137003 -0.050971 -0.013487  0.022933
# 9      37.0 -0.004999  0.074385 -0.145391 -0.059874  0.003164  0.048910
# 10     37.0  0.008593  0.131800 -0.441856 -0.012621  0.021118  0.055775
# 11     37.0  0.006227  0.066173 -0.115643 -0.029412  0.006554  0.027465
# 12     37.0  0.017257  0.059329 -0.086610 -0.011042  0.007291  0.029060
#
#            max
# Date
# 1     0.135294
# 2     0.114816
# 3     0.102177
# 4     0.204120
# 5     0.143618
# 6     0.094518
# 7     0.132244
# 8     0.074079
# 9     0.135474
# 10    0.342440
# 11    0.203294
# 12    0.284677

# %%
monthly_return = test_df.calendar_month_return()
monthly_return = pd.DataFrame(monthly_return)

# %% [markdown]
# if x consecutive month goes down, what happen afterward?

# %%
hsi = yf.download('^HSI', start=from_beginning, interval='1mo')
hsi
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 1987-01-01   2540.100098   2614.899902   2449.899902   2553.300049
# 1987-02-01   2585.199951   2879.000000   2585.199951   2877.899902
# 1987-03-01   2894.300049   2939.100098   2629.300049   2713.800049
# 1987-04-01   2695.899902   2785.500000   2589.500000   2659.899902
# 1987-05-01   2685.399902   2950.800049   2685.399902   2950.800049
# ...                  ...           ...           ...           ...
# 2024-04-01  16811.740234  18031.160156  16044.450195  17763.029297
# 2024-05-01  17760.679688  19706.119141  17740.619141  18079.609375
# 2024-06-01  18283.560547  18724.619141  17583.189453  17718.609375
# 2024-07-01  17669.419922  18317.310547  16924.580078  17344.599609
# 2024-08-01  17327.849609  17685.859375  16441.439453  17502.960938
#
#                Adj Close       Volume
# Date
# 1987-01-01   2553.300049            0
# 1987-02-01   2877.899902            0
# 1987-03-01   2713.800049            0
# 1987-04-01   2659.899902            0
# 1987-05-01   2950.800049            0
# ...                  ...          ...
# 2024-04-01  17763.029297  60561227500
# 2024-05-01  18079.609375  74518270400
# 2024-06-01  17718.609375  54373516600
# 2024-07-01  17344.599609  56317820700
# 2024-08-01  17502.960938  29611224200
#
# [452 rows x 6 columns]
